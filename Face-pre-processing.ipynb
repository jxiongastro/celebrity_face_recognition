# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai import *
from fastai.vision import *
from pathlib import Path
from PIL import Image as PImage
import face_recognition

# %%
path_img = Path('../image-classify-celeb')
path_face = Path('../image-classify-celeb-face')

# %%
for subfolder in ['train', 'test', 'valid']:
    path = path_img/subfolder
    opath = path_face/subfolder
    opath.mkdir()
    for label_folders in path.ls():
        if (path/label_folders).is_dir():
            path_label = path/label_folders
            opath_label = opath/label_folders
            opath_label.mkdir()
            inx = 0
            for img in sorted(path_label.glob('*.jpg')):
                image = face_recognition.load_image_file(img)
                face_locations = face_recognition.face_locations(image, model="cnn")
                
                for face_location in face_locations:

                    # Print the location of each face in this image
                    top, right, bottom, left = face_location
                    #print("A face is located at pixel location Top: {}, Left: {}, Bottom: {}, Right: {}".format(top, left, bottom, right))

                    # You can access the actual face itself like this:
                    face_image = image[top:bottom, left:right]
                    pil_image = PImage.fromarray(face_image)
                    ofame = 'face_' + str(inx)+'.jpg'
                    print(opath_label/ofame, "A face is located at pixel location Top: {}, Left: {}, Bottom: {}, Right: {}".format(top, left, bottom, right))
                    pil_image.save(opath_label/ofame)
                    inx += 1
# Out:
# ../image-classify-celeb-face/train/fahrin-ahmad/face_0.jpg A face is located at pixel location Top: 39, Left: 252, Bottom: 157, Right: 370
# ../image-classify-celeb-face/train/fahrin-ahmad/face_1.jpg A face is located at pixel location Top: 101, Left: 186, Bottom: 242, Right: 328
# ../image-classify-celeb-face/train/fahrin-ahmad/face_2.jpg A face is located at pixel location Top: 16, Left: 228, Bottom: 134, Right: 346
# ../image-classify-celeb-face/train/fahrin-ahmad/face_3.jpg A face is located at pixel location Top: 213, Left: 236, Bottom: 355, Right: 378
# ../image-classify-celeb-face/train/fahrin-ahmad/face_4.jpg A face is located at pixel location Top: 0, Left: 284, Bottom: 192, Right: 488
# ../image-classify-celeb-face/train/fahrin-ahmad/face_5.jpg A face is located at pixel location Top: 61, Left: 303, Bottom: 231, Right: 473
# ../image-classify-celeb-face/train/fahrin-ahmad/face_6.jpg A face is located at pixel location Top: 99, Left: 91, Bottom: 303, Right: 295
# ...
